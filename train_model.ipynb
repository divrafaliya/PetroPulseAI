# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# 1. Load data (Set date as index)
df = pd.read_csv('cleaned_fuel_prices.csv', index_col='date')
data = df.values

# 2. Create Windowed Sequences
# We use the past 10 days to predict the 11th day
def create_sequences(data, window_size=10):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)

X, y = create_sequences(data, window_size=10)

# 3. Split: 80% Train, 20% Test
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# 4. Define LSTM Architecture
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(10, X.shape[2])),
    Dropout(0.2),
    LSTM(50),
    Dropout(0.2),
    Dense(X.shape[2]) # Predicts Diesel, Petrol, and Brent prices
])

model.compile(optimizer='adam', loss='mse')

# 5. Start Training
print("Training the PetroPulseAI brain...")
history = model.fit(X_train, y_train, epochs=20, batch_size=16, validation_data=(X_test, y_test))

# 6. Save the outputs
model.save('petropulse_model.h5')
print("Model saved as petropulse_model.h5")
# Out:
# Training the PetroPulseAI brain...
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - loss: 0.1841 - val_loss: 0.0336
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0301 - val_loss: 0.0202
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0182 - val_loss: 0.0043
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0163 - val_loss: 0.0020
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0150 - val_loss: 0.0035
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0139 - val_loss: 0.0020
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0145 - val_loss: 0.0016
# Epoch 8/20
# ...
